# %% [markdown]
# <a href="https://colab.research.google.com/github/arun1267/4545/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
stu=['Dinnu','chinnu','minnu','kanna','munna','nana']
mark=[10,20,30,10,20,30]
plt.bar(stu,mark)
# Out:
# <BarContainer object of 6 artists>
